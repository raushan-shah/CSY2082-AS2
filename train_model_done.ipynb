# %% [markdown]
# # importing the important libraries

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import warnings
warnings.filterwarnings('ignore')

# %%
# TensorFlow and Keras imports
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models, regularizers, callbacks
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.utils.class_weight import compute_class_weight

# %% [markdown]
# # defining some important constants

# %%
data_dir = "data"
img_size = (224, 224)
img_channels = 3
batch_size = 8

# %% [markdown]
# # loading the data using, and dividing into training and testing

# %%
train = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    image_size=img_size,
    batch_size=batch_size,
    color_mode='rgb',
    shuffle=True,
    validation_split=0.2,
    subset='training',
    seed=50)
test = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    image_size=img_size,
    batch_size=batch_size,
    color_mode='rgb',
    shuffle=True,
    validation_split=0.2,
    subset='validation',
    seed=50)
# Out:
# Found 279 files belonging to 5 classes.
# Using 224 files for training.
# Found 279 files belonging to 5 classes.
# Using 55 files for validation.

# %%
train.class_names
# Out:
# ['dipak', 'me', 'ram', 'shyam', 'unknown']

# %% [markdown]
# # defining the labels of our model's prediction

# %%
class_names = train.class_names
num_classes = len(class_names)

# %% [markdown]
# # calculating weights of each classes

# %%
# Check validation set distribution
val_labels = []
for _, labels in test:
    val_labels.extend(labels.numpy())

val_counts = np.bincount(np.array(val_labels, dtype=np.int32), minlength=num_classes)
print("\nValidation set distribution:")
for i, class_name in enumerate(class_names):
    print(f"{class_name}: {val_counts[i]} images")
# Out:
# Validation set distribution:
# dipak: 6 images
# me: 16 images
# ram: 12 images
# shyam: 6 images
# unknown: 15 images

# %%
import numpy as np
all_labels = []
for _, labels in train:
    all_labels.extend(labels.numpy())
#calculating class weights of the data
class_weights = compute_class_weight(
    'balanced',
    classes=np.arange(num_classes),
    y=np.array(all_labels)
)
class_weight_dict = {i: w for i, w in enumerate(class_weights)}#calculating class weights

# Check class distribution and enhance weights
from collections import Counter
class_counts = Counter(all_labels)
print("\nClass distribution in training set:")
for i, class_name in enumerate(class_names):
    print(f"{class_name}: {class_counts[i]} images")

# trying to enhance the weights for classes with fewer data
class_weight_dict = {i: w**1.5 for i, w in enumerate(class_weights)}  # class_weight after enhancement
print("\nEnhanced class weights:")
for i, class_name in enumerate(class_names):
    print(f"{class_name}: {class_weight_dict[i]:.3f}")
# Out:
# Class distribution in training set:
# dipak: 54 images
# me: 54 images
# ram: 32 images
# shyam: 44 images
# unknown: 40 images
#
# Enhanced class weights:
# dipak: 0.756
# me: 0.756
# ram: 1.657
# shyam: 1.027
# unknown: 1.185

# %% [markdown]
# # defining the layers of our model

# %%
normalization_layer = layers.Rescaling(1./255)
# normalizing the image by diving by 255

# %%
#using data augmentation, because we have few image samples
augmentation_layer = keras.Sequential([
    layers.RandomRotation(factor=0.05, fill_mode='reflect'),
    layers.RandomZoom(height_factor=0.05, width_factor=0.05, fill_mode='reflect'),
    layers.RandomBrightness(factor=0.05),
], name="augmentation_layer")

# %%
#defining a preprocess function to preprocess the images loaded
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
def preprocess(image, label):
    image = preprocess_input(image)
    return image, label

# %%
# function to apply data augmentation
def apply_augmentation(x, y):
    x = augmentation_layer(x, training=True)
    return x, y

# %%
train_x = train.map(preprocess).map(apply_augmentation)#applying the preprocessing and augmentation to our training data
test_x = test.map(preprocess)#and applying preprocessing to our test/validation data

# %%
train_x
# Out:
# <_MapDataset element_spec=(TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
#using the prebuilt methods for faster processing
def configure_dataset(dataset):
    return dataset.cache().prefetch(buffer_size=tf.data.AUTOTUNE)

train_x = configure_dataset(train_x)
test_x = configure_dataset(test_x)

# %%
# I've decided to use MobileNetV2 as our base model, for feature extraction and fine tuining
base_model = MobileNetV2(
            input_shape=img_size + (img_channels,),#input shape = (128,128,3)
            include_top=False,           # Remove ImageNet classification head
            weights='imagenet',          # using the weights of the imagenet on mobilenet's architecture
            pooling='avg'                
        )

# %%
#freezing the layers of the base model
base_model.trainable = False

# %%
trainable_count = sum([layer.trainable for layer in base_model.layers])
print(f"   Frozen layers: {len(base_model.layers) - trainable_count}")
print(f"   Trainable layers: {trainable_count}")
# Out:
#    Frozen layers: 155
#    Trainable layers: 0

# %% [markdown]
# # building the model

# %%
from tensorflow.keras import regularizers
regularizer = regularizers.l2(0.0001) #using L2 regularizer with 0.0001 lambda to help prevent overfitting

# %%
#building the model
inputs = keras.Input(shape=img_size+(img_channels,), name='input_layer')
x = base_model(inputs, training=False)

# Much simpler architecture for small dataset
x = layers.Dropout(0.1)(x)
x = layers.Dense(64, activation='relu', kernel_regularizer=regularizer)(x)
x = layers.BatchNormalization()(x)
outputs = layers.Dense(num_classes, activation='softmax', name='output_layer')(x)

model = models.Model(inputs=inputs, outputs=outputs)

# %%
#let's chek our model's architecture
model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenetv2_1.00_224            │ (None, 1280)           │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │        81,984 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_layer (Dense)            │ (None, 5)              │           325 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,340,549 (8.93 MB)
#  Trainable params: 82,437 (322.02 KB)
#  Non-trainable params: 2,258,112 (8.61 MB)

# %%
#creating a checkpoint to save the model whenever it hits the best accuracy
checkpoint_cb = callbacks.ModelCheckpoint(
    'palm_model.keras',
    monitor='val_accuracy',#comparing the validation accuracy
    save_best_only=True,
    mode='max',#save with the highest accuracy
    verbose=1#logging info 
)
#adding earlystopping callback to stop training if the model's performance doesn't increase after 25 epoches
early_stop_cb = callbacks.EarlyStopping(
    monitor='val_accuracy',
    patience=25,# wait for 25 epoches
    restore_best_weights=True,#choose the best weight and stop
    verbose=1
)
# another one to reduce the learning rate based on the improvements on validation loss
reduce_lr_cb = callbacks.ReduceLROnPlateau(
    monitor='val_loss',#look at the validation loss
    factor=0.5,#reduce the learning rate by 0.5
    patience=8,#wait for 8 epoches
    min_lr=1e-7,#minimum value of learning rate
    verbose=1
)

# %%
#compiling the model
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

# %% [markdown]
# # Training the model (with base model freezed)

# %%
#training the model, first phase
train_1 = model.fit(
    train_x,
    epochs=50,#going for 30 epoches, as lower epoches didn't worked out well, and we do have callbacks for stopping
    validation_data=test_x,#giving the validation data
    callbacks=[checkpoint_cb, early_stop_cb, reduce_lr_cb],#adding the callbacks
    class_weight = class_weight_dict,#passing the class weights
    verbose=1
)
# Out:
# Epoch 1/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.2791 - loss: 1.9793
# Epoch 1: val_accuracy improved from None to 0.23636, saving model to best_model.keras
#
# Epoch 1: finished saving model to best_model.keras
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 15s 292ms/step - accuracy: 0.2946 - loss: 1.7583 - val_accuracy: 0.2364 - val_loss: 1.9180 - learning_rate: 5.0000e-04
# Epoch 2/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.4224 - loss: 1.4996
# Epoch 2: val_accuracy improved from 0.23636 to 0.25455, saving model to best_model.keras
#
# Epoch 2: finished saving model to best_model.keras
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.4196 - loss: 1.4522 - val_accuracy: 0.2545 - val_loss: 2.0770 - learning_rate: 5.0000e-04
# Epoch 3/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.4547 - loss: 1.3984
# Epoch 3: val_accuracy improved from 0.25455 to 0.43636, saving model to best_model.keras
#
# Epoch 3: finished saving model to best_model.keras
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 133ms/step - accuracy: 0.4286 - loss: 1.4122 - val_accuracy: 0.4364 - val_loss: 1.6056 - learning_rate: 5.0000e-04
# Epoch 4/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.5635 - loss: 1.1982
# Epoch 4: val_accuracy improved from 0.43636 to 0.47273, saving model to best_model.keras
#
# Epoch 4: finished saving model to best_model.keras
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 132ms/step - accuracy: 0.5268 - loss: 1.2058 - val_accuracy: 0.4727 - val_loss: 1.4015 - learning_rate: 5.0000e-04
# Epoch 5/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.6038 - loss: 1.0859
# Epoch 5: val_accuracy improved from 0.47273 to 0.56364, saving model to best_model.keras
#
# Epoch 5: finished saving model to best_model.keras
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - accuracy: 0.5848 - loss: 1.1205 - val_accuracy: 0.5636 - val_loss: 1.4323 - learning_rate: 5.0000e-04
# Epoch 6/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.5409 - loss: 1.1938
# Epoch 6: val_accuracy improved from 0.56364 to 0.60000, saving model to best_model.keras
#
# Epoch 6: finished saving model to best_model.keras
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 131ms/step - accuracy: 0.5402 - loss: 1.1864 - val_accuracy: 0.6000 - val_loss: 1.2928 - learning_rate: 5.0000e-04
# Epoch 7/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.5919 - loss: 1.0713
# Epoch 7: val_accuracy did not improve from 0.60000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - accuracy: 0.5804 - loss: 1.0999 - val_accuracy: 0.5818 - val_loss: 1.2287 - learning_rate: 5.0000e-04
# Epoch 8/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.5512 - loss: 1.0993
# Epoch 8: val_accuracy did not improve from 0.60000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - accuracy: 0.5580 - loss: 1.0852 - val_accuracy: 0.6000 - val_loss: 1.1308 - learning_rate: 5.0000e-04
# Epoch 9/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.5969 - loss: 1.0911
# Epoch 9: val_accuracy improved from 0.60000 to 0.63636, saving model to best_model.keras
#
# Epoch 9: finished saving model to best_model.keras
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 142ms/step - accuracy: 0.5893 - loss: 1.0968 - val_accuracy: 0.6364 - val_loss: 1.0546 - learning_rate: 5.0000e-04
# Epoch 10/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.6127 - loss: 1.0463
# Epoch 10: val_accuracy improved from 0.63636 to 0.69091, saving model to best_model.keras
#
# Epoch 10: finished saving model to best_model.keras
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 145ms/step - accuracy: 0.5848 - loss: 1.0592 - val_accuracy: 0.6909 - val_loss: 0.9316 - learning_rate: 5.0000e-04
# Epoch 11/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.6135 - loss: 1.0584
# Epoch 11: val_accuracy did not improve from 0.69091
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - accuracy: 0.5804 - loss: 1.0974 - val_accuracy: 0.4364 - val_loss: 1.3052 - learning_rate: 5.0000e-04
# Epoch 12/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.5677 - loss: 1.0832
# Epoch 12: val_accuracy did not improve from 0.69091
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - accuracy: 0.5848 - loss: 1.0525 - val_accuracy: 0.5091 - val_loss: 1.1078 - learning_rate: 5.0000e-04
# Epoch 13/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.6520 - loss: 0.9754
# Epoch 13: val_accuracy did not improve from 0.69091
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - accuracy: 0.5982 - loss: 1.0301 - val_accuracy: 0.5091 - val_loss: 1.1918 - learning_rate: 5.0000e-04
# Epoch 14/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.6100 - loss: 1.0166
# Epoch 14: val_accuracy did not improve from 0.69091
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - accuracy: 0.5982 - loss: 1.0191 - val_accuracy: 0.6364 - val_loss: 1.0759 - learning_rate: 5.0000e-04
# Epoch 15/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.6364 - loss: 0.9849
# Epoch 15: val_accuracy did not improve from 0.69091
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.6339 - loss: 0.9870 - val_accuracy: 0.6545 - val_loss: 1.0818 - learning_rate: 5.0000e-04
# Epoch 16/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.6228 - loss: 0.9523
# Epoch 16: val_accuracy did not improve from 0.69091
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - accuracy: 0.5982 - loss: 0.9758 - val_accuracy: 0.6545 - val_loss: 0.8790 - learning_rate: 5.0000e-04
# Epoch 17/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.6019 - loss: 0.9640
# Epoch 17: val_accuracy improved from 0.69091 to 0.70909, saving model to best_model.keras
#
# Epoch 17: finished saving model to best_model.keras
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 129ms/step - accuracy: 0.6071 - loss: 0.9438 - val_accuracy: 0.7091 - val_loss: 0.8665 - learning_rate: 5.0000e-04
# Epoch 18/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.6303 - loss: 0.9709
# Epoch 18: val_accuracy did not improve from 0.70909
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.6116 - loss: 0.9711 - val_accuracy: 0.7091 - val_loss: 0.8424 - learning_rate: 5.0000e-04
# Epoch 19/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.6066 - loss: 0.9683
# Epoch 19: val_accuracy did not improve from 0.70909
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - accuracy: 0.5982 - loss: 0.9879 - val_accuracy: 0.7091 - val_loss: 0.8031 - learning_rate: 5.0000e-04
# Epoch 20/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.6381 - loss: 0.9499
# Epoch 20: val_accuracy did not improve from 0.70909
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - accuracy: 0.6384 - loss: 0.9616 - val_accuracy: 0.6182 - val_loss: 0.9051 - learning_rate: 5.0000e-04
# Epoch 21/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.6080 - loss: 0.9514
# Epoch 21: val_accuracy did not improve from 0.70909
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - accuracy: 0.6473 - loss: 0.9252 - val_accuracy: 0.6727 - val_loss: 0.8644 - learning_rate: 5.0000e-04
# Epoch 22/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.6300 - loss: 0.9393
# Epoch 22: val_accuracy did not improve from 0.70909
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - accuracy: 0.6205 - loss: 0.9456 - val_accuracy: 0.6727 - val_loss: 0.7577 - learning_rate: 5.0000e-04
# Epoch 23/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.6616 - loss: 0.9246
# Epoch 23: val_accuracy did not improve from 0.70909
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - accuracy: 0.6518 - loss: 0.9208 - val_accuracy: 0.6909 - val_loss: 0.7641 - learning_rate: 5.0000e-04
# Epoch 24/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.6425 - loss: 0.8870
# Epoch 24: val_accuracy did not improve from 0.70909
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - accuracy: 0.6205 - loss: 0.9143 - val_accuracy: 0.6909 - val_loss: 0.7283 - learning_rate: 5.0000e-04
# Epoch 25/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.7082 - loss: 0.8790
# Epoch 25: val_accuracy did not improve from 0.70909
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - accuracy: 0.6786 - loss: 0.8836 - val_accuracy: 0.6545 - val_loss: 0.8128 - learning_rate: 5.0000e-04
# Epoch 26/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.5942 - loss: 0.9263
# Epoch 26: val_accuracy did not improve from 0.70909
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - accuracy: 0.6161 - loss: 0.9219 - val_accuracy: 0.6727 - val_loss: 0.7938 - learning_rate: 5.0000e-04
# Epoch 27/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.6518 - loss: 0.8611
# Epoch 27: val_accuracy improved from 0.70909 to 0.72727, saving model to best_model.keras
#
# Epoch 27: finished saving model to best_model.keras
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 137ms/step - accuracy: 0.6250 - loss: 0.8881 - val_accuracy: 0.7273 - val_loss: 0.7500 - learning_rate: 5.0000e-04
# Epoch 28/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.6663 - loss: 0.9047
# Epoch 28: val_accuracy did not improve from 0.72727
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - accuracy: 0.6652 - loss: 0.8771 - val_accuracy: 0.6727 - val_loss: 0.7660 - learning_rate: 5.0000e-04
# Epoch 29/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.6467 - loss: 0.9245
# Epoch 29: val_accuracy improved from 0.72727 to 0.74545, saving model to best_model.keras
#
# Epoch 29: finished saving model to best_model.keras
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 135ms/step - accuracy: 0.6518 - loss: 0.8923 - val_accuracy: 0.7455 - val_loss: 0.7352 - learning_rate: 5.0000e-04
# Epoch 30/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.6470 - loss: 0.8784
# Epoch 30: val_accuracy did not improve from 0.74545
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - accuracy: 0.6205 - loss: 0.8843 - val_accuracy: 0.2909 - val_loss: 2.0114 - learning_rate: 5.0000e-04
# Epoch 31/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.6504 - loss: 0.8766
# Epoch 31: val_accuracy did not improve from 0.74545
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.6652 - loss: 0.8599 - val_accuracy: 0.7091 - val_loss: 0.8904 - learning_rate: 5.0000e-04
# Epoch 32/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.6602 - loss: 0.8846
# Epoch 32: val_accuracy did not improve from 0.74545
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - accuracy: 0.6696 - loss: 0.8675 - val_accuracy: 0.6182 - val_loss: 0.9108 - learning_rate: 5.0000e-04
# Epoch 33/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.6375 - loss: 0.9154
# Epoch 33: val_accuracy improved from 0.74545 to 0.76364, saving model to best_model.keras
#
# Epoch 33: finished saving model to best_model.keras
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - accuracy: 0.6607 - loss: 0.8719 - val_accuracy: 0.7636 - val_loss: 0.6149 - learning_rate: 5.0000e-04
# Epoch 34/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.6232 - loss: 0.8730
# Epoch 34: val_accuracy did not improve from 0.76364
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - accuracy: 0.6250 - loss: 0.8732 - val_accuracy: 0.6909 - val_loss: 0.7639 - learning_rate: 5.0000e-04
# Epoch 35/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.6390 - loss: 0.8735
# Epoch 35: val_accuracy did not improve from 0.76364
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - accuracy: 0.6607 - loss: 0.8421 - val_accuracy: 0.7091 - val_loss: 0.7290 - learning_rate: 5.0000e-04
# Epoch 36/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.6612 - loss: 0.8523
# Epoch 36: val_accuracy did not improve from 0.76364
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - accuracy: 0.6518 - loss: 0.8500 - val_accuracy: 0.7273 - val_loss: 0.7389 - learning_rate: 5.0000e-04
# Epoch 37/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.6290 - loss: 0.8615
# Epoch 37: val_accuracy did not improve from 0.76364
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - accuracy: 0.6205 - loss: 0.8545 - val_accuracy: 0.7091 - val_loss: 0.7298 - learning_rate: 5.0000e-04
# Epoch 38/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.6679 - loss: 0.8481
# Epoch 38: val_accuracy did not improve from 0.76364
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - accuracy: 0.6473 - loss: 0.8804 - val_accuracy: 0.6909 - val_loss: 0.8032 - learning_rate: 5.0000e-04
# Epoch 39/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.6490 - loss: 0.8504
# Epoch 39: val_accuracy did not improve from 0.76364
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - accuracy: 0.6339 - loss: 0.8457 - val_accuracy: 0.6727 - val_loss: 0.9148 - learning_rate: 5.0000e-04
# Epoch 40/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.6341 - loss: 0.8835
# Epoch 40: val_accuracy improved from 0.76364 to 0.78182, saving model to best_model.keras
#
# Epoch 40: finished saving model to best_model.keras
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - accuracy: 0.6518 - loss: 0.8649 - val_accuracy: 0.7818 - val_loss: 0.7325 - learning_rate: 5.0000e-04
# Epoch 41/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.6172 - loss: 0.8841
# Epoch 41: val_accuracy did not improve from 0.78182
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - accuracy: 0.6518 - loss: 0.8504 - val_accuracy: 0.7636 - val_loss: 0.7025 - learning_rate: 5.0000e-04
# Epoch 42/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.6222 - loss: 0.9126
# Epoch 42: val_accuracy did not improve from 0.78182
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - accuracy: 0.6562 - loss: 0.8568 - val_accuracy: 0.7818 - val_loss: 0.6143 - learning_rate: 5.0000e-04
# Epoch 43/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.6742 - loss: 0.8565
# Epoch 43: val_accuracy did not improve from 0.78182
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.6473 - loss: 0.8831 - val_accuracy: 0.7818 - val_loss: 0.6450 - learning_rate: 5.0000e-04
# Epoch 44/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.6881 - loss: 0.8590
# Epoch 44: val_accuracy improved from 0.78182 to 0.83636, saving model to best_model.keras
#
# Epoch 44: finished saving model to best_model.keras
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 135ms/step - accuracy: 0.6786 - loss: 0.8364 - val_accuracy: 0.8364 - val_loss: 0.6402 - learning_rate: 5.0000e-04
# Epoch 45/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.6215 - loss: 0.8832
# Epoch 45: val_accuracy did not improve from 0.83636
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - accuracy: 0.6429 - loss: 0.8769 - val_accuracy: 0.7455 - val_loss: 0.7984 - learning_rate: 5.0000e-04
# Epoch 46/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.6623 - loss: 0.8721
# Epoch 46: val_accuracy did not improve from 0.83636
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - accuracy: 0.6473 - loss: 0.8637 - val_accuracy: 0.7818 - val_loss: 0.7537 - learning_rate: 5.0000e-04
# Epoch 47/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.6741 - loss: 0.8427
# Epoch 47: val_accuracy did not improve from 0.83636
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - accuracy: 0.6741 - loss: 0.8312 - val_accuracy: 0.8000 - val_loss: 0.6808 - learning_rate: 5.0000e-04
# Epoch 48/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.6799 - loss: 0.8046
# Epoch 48: val_accuracy did not improve from 0.83636
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - accuracy: 0.6652 - loss: 0.8149 - val_accuracy: 0.8182 - val_loss: 0.5836 - learning_rate: 5.0000e-04
# Epoch 49/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.6741 - loss: 0.8255
# Epoch 49: val_accuracy did not improve from 0.83636
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - accuracy: 0.6652 - loss: 0.8352 - val_accuracy: 0.7455 - val_loss: 0.8493 - learning_rate: 5.0000e-04
# Epoch 50/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.6906 - loss: 0.7919
# Epoch 50: val_accuracy did not improve from 0.83636
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - accuracy: 0.6964 - loss: 0.7968 - val_accuracy: 0.7636 - val_loss: 0.6985 - learning_rate: 5.0000e-04
# Restoring model weights from the end of the best epoch: 44.

# %% [markdown]
# # unfreezing the base model

# %%
base_model.trainable = True

# %%
for layer in base_model.layers[:-40]:
    layer.trainable = False#unfreezing only the last 10 layers of the base model

# %%
#freezing batch norm layers
for layer in base_model.layers:
    if isinstance(layer, layers.BatchNormalization):
        layer.trainable = False

# %%
trainable_count = sum([layer.trainable for layer in model.layers])
print(f"Trainable layers: {trainable_count}")
# Out:
# Trainable layers: 6

# %%
# recompiling the model after unfreezing some of the layers
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=5e-5),
    loss=keras.losses.SparseCategoricalCrossentropy(),
    metrics=['accuracy']
)

# %%
#training the model once again
train_2 = model.fit(
    train_x,
    epochs=30,  
    validation_data=test_x,
    class_weight=class_weight_dict,
    callbacks=[checkpoint_cb, early_stop_cb, reduce_lr_cb],
    verbose=1
)
# Out:
# Epoch 1/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.5208 - loss: 1.1777
# Epoch 1: val_accuracy did not improve from 0.83636
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 13s 183ms/step - accuracy: 0.5045 - loss: 1.1855 - val_accuracy: 0.7818 - val_loss: 1.4496 - learning_rate: 5.0000e-05
# Epoch 2/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.5478 - loss: 1.1237
# Epoch 2: val_accuracy did not improve from 0.83636
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 147ms/step - accuracy: 0.5670 - loss: 1.0903 - val_accuracy: 0.5273 - val_loss: 1.6842 - learning_rate: 5.0000e-05
# Epoch 3/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.5481 - loss: 1.0934
# Epoch 3: val_accuracy did not improve from 0.83636
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 138ms/step - accuracy: 0.5759 - loss: 1.0536 - val_accuracy: 0.6727 - val_loss: 1.0407 - learning_rate: 5.0000e-05
# Epoch 4/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.5530 - loss: 1.0944
# Epoch 4: val_accuracy did not improve from 0.83636
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - accuracy: 0.5580 - loss: 1.1037 - val_accuracy: 0.7455 - val_loss: 1.0951 - learning_rate: 5.0000e-05
# Epoch 5/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.6353 - loss: 0.9757
# Epoch 5: val_accuracy did not improve from 0.83636
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 132ms/step - accuracy: 0.6116 - loss: 0.9896 - val_accuracy: 0.6000 - val_loss: 1.0786 - learning_rate: 5.0000e-05
# Epoch 6/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.5954 - loss: 0.9534
# Epoch 6: val_accuracy improved from 0.83636 to 0.85455, saving model to best_model.keras
#
# Epoch 6: finished saving model to best_model.keras
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.6205 - loss: 0.9250 - val_accuracy: 0.8545 - val_loss: 0.5136 - learning_rate: 5.0000e-05
# Epoch 7/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.6361 - loss: 0.8972
# Epoch 7: val_accuracy did not improve from 0.85455
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - accuracy: 0.6161 - loss: 0.9160 - val_accuracy: 0.8364 - val_loss: 0.5413 - learning_rate: 5.0000e-05
# Epoch 8/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.5661 - loss: 0.9512
# Epoch 8: val_accuracy improved from 0.85455 to 0.96364, saving model to best_model.keras
#
# Epoch 8: finished saving model to best_model.keras
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 164ms/step - accuracy: 0.5848 - loss: 0.9120 - val_accuracy: 0.9636 - val_loss: 0.2146 - learning_rate: 5.0000e-05
# Epoch 9/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.6696 - loss: 0.8766
# Epoch 9: val_accuracy did not improve from 0.96364
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 143ms/step - accuracy: 0.6562 - loss: 0.8693 - val_accuracy: 0.8909 - val_loss: 0.4015 - learning_rate: 5.0000e-05
# Epoch 10/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.6417 - loss: 0.8941
# Epoch 10: val_accuracy did not improve from 0.96364
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 138ms/step - accuracy: 0.6473 - loss: 0.8777 - val_accuracy: 0.8000 - val_loss: 0.5960 - learning_rate: 5.0000e-05
# Epoch 11/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.6834 - loss: 0.8322
# Epoch 11: val_accuracy did not improve from 0.96364
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 137ms/step - accuracy: 0.6696 - loss: 0.8445 - val_accuracy: 0.7091 - val_loss: 0.7604 - learning_rate: 5.0000e-05
# Epoch 12/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.6063 - loss: 0.9251
# Epoch 12: val_accuracy did not improve from 0.96364
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 138ms/step - accuracy: 0.6205 - loss: 0.9064 - val_accuracy: 0.7455 - val_loss: 0.5967 - learning_rate: 5.0000e-05
# Epoch 13/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.6446 - loss: 0.8678
# Epoch 13: val_accuracy did not improve from 0.96364
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 137ms/step - accuracy: 0.6518 - loss: 0.8602 - val_accuracy: 0.8909 - val_loss: 0.3447 - learning_rate: 5.0000e-05
# Epoch 14/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.6647 - loss: 0.8826
# Epoch 14: val_accuracy did not improve from 0.96364
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 134ms/step - accuracy: 0.6696 - loss: 0.8554 - val_accuracy: 0.8545 - val_loss: 0.3642 - learning_rate: 5.0000e-05
# Epoch 15/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.6602 - loss: 0.8776
# Epoch 15: val_accuracy did not improve from 0.96364
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 138ms/step - accuracy: 0.6741 - loss: 0.8703 - val_accuracy: 0.9091 - val_loss: 0.2950 - learning_rate: 5.0000e-05
# Epoch 16/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.6230 - loss: 0.8822
# Epoch 16: val_accuracy did not improve from 0.96364
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 137ms/step - accuracy: 0.6696 - loss: 0.8452 - val_accuracy: 0.9273 - val_loss: 0.3223 - learning_rate: 5.0000e-05
# Epoch 17/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.6627 - loss: 0.8731
# Epoch 17: val_accuracy did not improve from 0.96364
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.6473 - loss: 0.8863 - val_accuracy: 0.9636 - val_loss: 0.3003 - learning_rate: 5.0000e-05
# Epoch 18/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.6153 - loss: 0.9330
# Epoch 18: val_accuracy did not improve from 0.96364
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 138ms/step - accuracy: 0.6027 - loss: 0.9158 - val_accuracy: 0.9091 - val_loss: 0.3184 - learning_rate: 5.0000e-05
# Epoch 19/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.6708 - loss: 0.8511
# Epoch 19: val_accuracy improved from 0.96364 to 0.98182, saving model to best_model.keras
#
# Epoch 19: finished saving model to best_model.keras
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 165ms/step - accuracy: 0.6473 - loss: 0.8698 - val_accuracy: 0.9818 - val_loss: 0.1587 - learning_rate: 5.0000e-05
# Epoch 20/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.6319 - loss: 0.8624
# Epoch 20: val_accuracy did not improve from 0.98182
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 139ms/step - accuracy: 0.6384 - loss: 0.8471 - val_accuracy: 0.8909 - val_loss: 0.2458 - learning_rate: 5.0000e-05
# Restoring model weights from the end of the best epoch: 19.

# %% [markdown]
# # Evaluating the model's performance

# %%
train_loss, train_acc = model.evaluate(train_x, verbose=1)
val_loss, val_acc = model.evaluate(test_x, verbose=1)
print(f"Training Accuracy: {train_acc*100:.2f}%")
print(f"Validation Accuracy: {val_acc*100:.2f}%")
# Out:
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step - accuracy: 0.4866 - loss: 1.1702
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - accuracy: 0.9818 - loss: 0.1587
# Training Accuracy: 48.66%
# Validation Accuracy: 98.18%

# %%
!

# %% [markdown]
# # visualizing the confusion matrix

# %%
from sklearn.metrics import classification_report, confusion_matrix

y_true = []
y_pred = []

for images, labels in test_x:
    preds = model.predict(images, verbose=0)#predicting each images
    y_true.extend(labels.numpy())#appending the labels/original value
    y_pred.extend(np.argmax(preds, axis=1))#appending the predicted value
#converting to numpy arrary for processing
y_true = np.array(y_true)
y_pred = np.array(y_pred)

#creating a classification_report object
print(classification_report(y_true, y_pred, target_names=class_names))

# creating the confusion matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names,
            yticklabels=class_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.tight_layout()
plt.show()
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#        dipak       1.00      1.00      1.00         6
#           me       1.00      0.94      0.97        16
#          ram       0.92      1.00      0.96        12
#        shyam       1.00      1.00      1.00         6
#      unknown       1.00      1.00      1.00        15
#
#     accuracy                           0.98        55
#    macro avg       0.98      0.99      0.99        55
# weighted avg       0.98      0.98      0.98        55

# %%
#saving the model for inference in future
model.save('palm_model.keras')
model.save_weights('PalmModel.weights.h5')

# %%
# This code is generated by AI.
def plot_history(history1, history2):
    fig, axes = plt.subplots(2, 2, figsize=(14, 10))
    
    colors = ['blue', 'green']
    
    for idx, (history, title) in enumerate(zip([history1, history2], ['Phase 1 (Frozen)', 'Phase 2 (Fine-tune)'])):
        # Accuracy
        axes[0, 0].plot(history.history['accuracy'], 
                        label=f'{title} Train', color=colors[idx], linestyle='-')
        axes[0, 0].plot(history.history['val_accuracy'], 
                        label=f'{title} Val', color=colors[idx], linestyle='--')
        
        # Loss
        axes[0, 1].plot(history.history['loss'], 
                        label=f'{title} Train', color=colors[idx], linestyle='-')
        axes[0, 1].plot(history.history['val_loss'], 
                        label=f'{title} Val', color=colors[idx], linestyle='--')
    
    axes[0, 0].set_title('Model Accuracy')
    axes[0, 0].set_xlabel('Epoch')
    axes[0, 0].set_ylabel('Accuracy')
    axes[0, 0].legend()
    axes[0, 0].grid(True)
    
    axes[0, 1].set_title('Model Loss')
    axes[0, 1].set_xlabel('Epoch')
    axes[0, 1].set_ylabel('Loss')
    axes[0, 1].legend()
    axes[0, 1].grid(True)
    
    # Combined accuracy
    axes[1, 0].plot(history1.history['accuracy'], 
                    label='Phase 1 Train', color='blue', linestyle='-')
    axes[1, 0].plot(history1.history['val_accuracy'], 
                    label='Phase 1 Val', color='blue', linestyle='--')
    axes[1, 0].plot(range(len(history1.history['accuracy'])), 
                    history2.history['accuracy'], label='Phase 2 Train', color='green', linestyle='-')
    axes[1, 0].plot(range(len(history1.history['accuracy'])), 
                    history2.history['val_accuracy'], label='Phase 2 Val', color='green', linestyle='--')
    axes[1, 0].axvline(x=len(history1.history['accuracy'])-1, 
                       color='red', linestyle=':', label='Phase Transition')
    axes[1, 0].set_title('Combined Accuracy (All Epochs)')
    axes[1, 0].set_xlabel('Epoch')
    axes[1, 0].set_ylabel('Accuracy')
    axes[1, 0].legend()
    axes[1, 0].grid(True)
    
    axes[1, 1].axis('off')
    
    plt.tight_layout()
    plt.show()

plot_history(train_1, train_2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[66], line 54
#      51     plt.tight_layout()
#      52     plt.show()
# ---> 54 plot_history(history_phase1, history_phase2)
#
# Cell In[66], line 37, in plot_history(history1, history2)
#      33 axes[1, 0].plot(history1.history['accuracy'],
#      34                 label='Phase 1 Train', color='blue', linestyle='-')
#      35 axes[1, 0].plot(history1.history['val_accuracy'],
#      36                 label='Phase 1 Val', color='blue', linestyle='--')
# ---> 37 axes[1, 0].plot(range(len(history1.history['accuracy'])),
#      38                 history2.history['accuracy'], label='Phase 2 Train', color='green', linestyle='-')
#      39 axes[1, 0].plot(range(len(history1.history['accuracy'])),
#      40                 history2.history['val_accuracy'], label='Phase 2 Val', color='green', linestyle='--')
#      41 axes[1, 0].axvline(x=len(history1.history['accuracy'])-1,
#      42                    color='red', linestyle=':', label='Phase Transition')
#
# File c:\Users\acer\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axes\_axes.py:1777, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1534 """
#    1535 Plot y versus x as lines and/or markers.
#    1536
#    (...)   1774 (``'green'``) or hex strings (``'#008000'``).
#    1775 """
#    1776 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1777 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1778 for line in lines:
#    1779     self.add_line(line)
#
# File c:\Users\acer\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axes\_base.py:297, in _process_plot_var_args.__call__(self, axes, data, return_kwargs, *args, **kwargs)
#     295     this += args[0],
#     296     args = args[1:]
# --> 297 yield from self._plot_args(
#     298     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey,
#     299     return_kwargs=return_kwargs
#     300 )
#
# File c:\Users\acer\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axes\_base.py:494, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     491     axes.yaxis.update_units(y)
#     493 if x.shape[0] != y.shape[0]:
# --> 494     raise ValueError(f"x and y must have same first dimension, but "
#     495                      f"have shapes {x.shape} and {y.shape}")
#     496 if x.ndim > 2 or y.ndim > 2:
#     497     raise ValueError(f"x and y can be no greater than 2D, but have "
#     498                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (50,) and (20,)

# %%
# Plot training history
plt.figure(figsize=(12, 4))

# Accuracy plot
plt.subplot(1, 2, 1)
plt.plot(hist.history['accuracy'], label='Train Accuracy')
plt.plot(hist.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Loss plot
plt.subplot(1, 2, 2)
plt.plot(hist.history['loss'], label='Train Loss')
plt.plot(hist.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()
